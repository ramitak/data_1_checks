# %%
# !pip install pandas
# Out:
# zsh:1: command not found: pip

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#import data from csv file

df = pd.read_csv('assets/movies_data.csv')
display(df)
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
#Creating a dictionery with 5 key values pairs.
movie = {
    'title' : 'The Godfather',
    'year' : 1972,
    'director' : 'Francis Ford Coppola',
    'genra' : ['Crime', 'Drama'],
    'cast' : ['Marlon Brando', 'Al Pacino', 'James Caan']
}

for key, value in movie.items():
    print(f"{key}: {value}")
# Out:
# title: The Godfather
# year: 1972
# director: Francis Ford Coppola
# genra: ['Crime', 'Drama']
# cast: ['Marlon Brando', 'Al Pacino', 'James Caan']

# %%
#creating a function to remove the unwanted rows from the data like "not rated" in this case.

#importing my dataset from csv
df = pd.read_csv('assets/movies_data.csv')

#Remove rows where the 'Rating' column equals 'Not Rated'
df.drop(df[df['rating'] == 'Not Rated'].index, inplace=True)
print(df)
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %% [markdown]
# # Using a python built-in functions to find something about the data

# %%
#Using a python built-in functions to find the lenght of something

#First Loading my data from a csv file
df = pd.read_csv('assets/movies_data.csv')

#Using len() function to find the number of movies
#Getting the number of movies in my dataset
num_movies = len(df)

print(num_movies)

#Using any() function to find the ratings that are above 7.0
ratings = df['rating']
if any(rating > 7.0 for rating in ratings):
    print('At least one movie has a rating above 7.0')
else:
    print('No movie has a rating above 7.0')
# Out:
# 250
# At least one movie has a rating above 7.0
